# %%
pwd
# Out:
# 'C:\\Users\\HP\\Desktop\\Y Python\\YOLO\\v7\\yolov7'

# %%
# %cd ..
# Out:
# C:\Users\HP\Desktop\Y Python\YOLO\v7

# %%
import os

# %%
train_img_path = "C:/Users/HP/Desktop/Y Python/YOLO/v7/train/images"
val_img_path = "C:/Users/HP/Desktop/Y Python/YOLO/v7/test/images"

# %%
#Training images
with open("C:/Users/HP/Desktop/Y Python/YOLO/v7/train.txt", "a+") as f:
  img_list = os.listdir(train_img_path)
  for img in img_list:
    f.write(os.path.join(train_img_path,img+'\n'))
  print("Done")
# Out:
# Done

# %%
# Validation Image
with open('C:/Users/HP/Desktop/Y Python/YOLO/v7/test.txt', "a+") as f:
  img_list = os.listdir(val_img_path)
  for img in img_list:
    f.write(os.path.join(val_img_path,img+'\n'))
  print("Done")
# Out:
# Done

# %%
# !python train.py --batch 16 --cfg cfg/training/custom_yolov7.yaml --epochs 100 --data /content/yolov7/data/custom.yaml --weights 'yolov7.pt' --device cpu

# %%
# !python train.py --img 320 --batch 4 --epochs 30 --data data.yaml  --weights yolov7.pt  --device cpu --cfg yolov7_custom.yaml
# Out:
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)
#
# autoanchor: Analyzing anchors... anchors/target = 5.14, Best Possible Recall (BPR) = 1.0000
#                  all          29         376     0.00929      0.0108      0.0014    0.000301
#                  all          29         376      0.0341       0.287      0.0425      0.0118
#                  all          29         376       0.441      0.0657      0.0112     0.00224
#                  all          29         376       0.405       0.357       0.164      0.0758
#                  all          29         376       0.574       0.178      0.0638      0.0177
#                  all          29         376      0.0746       0.511       0.184      0.0704
#                  all          29         376       0.432        0.57       0.279       0.128
#                  all          29         376       0.616       0.438       0.384       0.232
# ...

# %%
pwd
# Out:
# 'C:\\Users\\HP\\Desktop\\Y Python\\YOLO\\v7\\yolov7'

# %%
# %cd yolov7
# Out:
# C:\Users\HP\Desktop\Y Python\YOLO\v7\yolov7
# C:\Users\HP\anaconda3\envs\lokesh\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !python detect.py --weights runs/train/exp7/weights/best.pt --source "C:/Users/HP/Desktop/Y Python/YOLO/v7/test/images/685b860d412b91f5d4f7f9e643b84452_jpg.rf.2d78193e4021ae5ffb49ecd1060bebd7.jpg"  --device cpu --view-img
# Out:
# Namespace(weights=['runs/train/exp7/weights/best.pt'], source='C:/Users/HP/Desktop/Y Python/YOLO/v7/test/images/685b860d412b91f5d4f7f9e643b84452_jpg.rf.2d78193e4021ae5ffb49ecd1060bebd7.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='cpu', view_img=True, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# 2 black-kings, 1 black-pawn, 1 white-king, 4 white-pawns, 1 white-rook, Done. (1532.6ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\exp3\685b860d412b91f5d4f7f9e643b84452_jpg.rf.2d78193e4021ae5ffb49ecd1060bebd7.jpg
# Done. (1.600s)
# YOLOR  2024-6-2 torch 2.3.0+cpu CPU
#
# ...
