# %%
# !git clone https://github.com/meituan/YOLOv6
# Out:
# fatal: destination path 'YOLOv6' already exists and is not an empty directory.

# %%
pwd
# Out:
# 'C:\\Users\\HP\\Desktop\\Y Python\\YOLO\\yolo_v6'

# %%
# %cd YOLOv6
# Out:
# C:\Users\HP\Desktop\Y Python\YOLO\yolo_v6\YOLOv6
# C:\Users\HP\anaconda3\envs\lokesh\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %cd ..
# Out:
# C:\Users\HP\Desktop\Y Python\YOLO\yolo_v6\YOLOv6

# %%
# !python tools/train.py --batch 8 --conf configs/yolov6s_finetune.py --data data.yaml --device cpu --epochs 100

# !python tools/train.py --img 320 --batch 4 --epochs 20 --data "C:/Users/HP/Desktop/Y Python/YOLO/yolo_v6/data.yaml" --conf ./configs/yolov6s_finetune.py --name yolov6s_results --cache --device cpu
# Out:
# self.imgs: 800
# self.imgs: 200
# 2024-06-02 17:57:59.425759: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-02 17:58:01.141844: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Using CPU for training...
# ...

# %%
# !python tools/eval.py --data "C:/Users/HP/Desktop/Y Python/YOLO/yolo_v6/data.yaml"  --weights runs/train/yolov6s_results8/weights/best_ckpt.pt --device cpu
# Out:
# Namespace(data='C:/Users/HP/Desktop/Y Python/YOLO/yolo_v6/data.yaml', weights='runs/train/yolov6s_results8/weights/best_ckpt.pt', batch_size=32, img_size=640, conf_thres=0.03, iou_thres=0.65, task='val', device='cpu', half=False, save_dir='runs/val/', name='exp', shrink_size=0, infer_on_rect=True, reproduce_640_eval=False, eval_config_file='./configs/experiment/eval_640_repro.py', do_coco_metric=True, do_pr_metric=False, plot_curve=True, plot_confusion_matrix=False, verbose=False, config_file='', specific_shape=False, height=None, width=None)
# Loading checkpoint from runs/train/yolov6s_results8/weights/best_ckpt.pt
#
# Fusing model...
# Switch model to deploy modality.
# Model Summary: Params: 18.50M, Gflops: 45.17
# img record infomation path is:C:/Users/HP/Desktop/Y Python/YOLO/yolo_v6/dataset/images\.val_cache.json
# Val: Checking formats of labels with 8 process(es):
#
#   0%|          | 0/200 [00:00<?, ?it/s]
# ...

# %%
from IPython.display import Image
Image(filename = "C:/Users/HP/Desktop/Y Python/YOLO/yolo_v6/dataset/images/val/06c2372fb9bad10e.jpg", width=1000)

# %%
# !python tools/infer.py --weights runs/train/yolov6s_results8/weights/best_ckpt.pt --source "C:/Users/HP/Desktop/Y Python/YOLO/yolo_v6/dataset/images/val" --device cpu --yaml "C:/Users/HP/Desktop/Y Python/YOLO/yolo_v6/data.yaml" --conf-thres 0.007
# Out:
# Namespace(weights='runs/train/yolov6s_results8/weights/best_ckpt.pt', source='C:/Users/HP/Desktop/Y Python/YOLO/yolo_v6/dataset/images/val', webcam=False, webcam_addr='0', yaml='C:/Users/HP/Desktop/Y Python/YOLO/yolo_v6/data.yaml', img_size=[640, 640], conf_thres=0.007, iou_thres=0.45, max_det=1000, device='cpu', save_txt=False, not_save_img=False, save_dir=None, view_img=False, classes=None, agnostic_nms=False, project='runs/inference', name='exp', hide_labels=False, hide_conf=False, half=False)
# Save directory already existed
# Loading checkpoint from runs/train/yolov6s_results8/weights/best_ckpt.pt
#
# Fusing model...
# Switch model to deploy modality.
#
# ...
# 100%|##########| 200/200 [02:09<00:00,  1.54it/s]
# Results saved to runs/inference\exp

# %%
from IPython.display import Image
Image(filename = "C:/Users/HP/Desktop/Y Python/YOLO/yolo_v6/YOLOv6/runs/inference/exp/06c2372fb9bad10e.jpg", width=1000)

# %%
# !python tools/infer.py -h
# Out:
# usage: infer.py [-h] [--weights WEIGHTS] [--source SOURCE] [--webcam]
#                 [--webcam-addr WEBCAM_ADDR] [--yaml YAML]
#                 [--img-size IMG_SIZE [IMG_SIZE ...]] [--conf-thres CONF_THRES]
#                 [--iou-thres IOU_THRES] [--max-det MAX_DET] [--device DEVICE]
#                 [--save-txt] [--not-save-img] [--save-dir SAVE_DIR]
#                 [--view-img] [--classes CLASSES [CLASSES ...]]
#                 [--agnostic-nms] [--project PROJECT] [--name NAME]
#                 [--hide-labels] [--hide-conf] [--half]
#
# YOLOv6 PyTorch Inference.
#
# options:
#   -h, --help            show this help message and exit
#   --weights WEIGHTS     model path(s) for inference.
#   --source SOURCE       the source path, e.g. image-file/dir.
#   --webcam              whether to use webcam.
#   --webcam-addr WEBCAM_ADDR
#                         the web camera address, local camera or rtsp address.
#   --yaml YAML           data yaml file.
# ...
